# %%
import math
i = math.sqrt(0.5**2 + 0.5**2)
print(f"i = {i:.2f}")
# Out:
# i = 0.71

# %%
import math
i = math.sqrt(0.34**2 + -0.37**2)
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-fc4d1b55c515> in <module>
#       1 import math
# ----> 2 i = math.sqrt(0.34**2 + -0.37**2)
#       3 print(i)
#
# ValueError: math domain error

# %%
import random as rnd
for x in range(1,10):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    print(f"x = {x:.2f}, y = {y:.2f}")
# Out:
# x = -0.38, y = 0.31
# x = -0.82, y = 0.44
# x = 0.86, y = 0.45
# x = 0.01, y = 0.83
# x = 0.14, y = 0.14
# x = 0.60, y = -0.19
# x = 0.25, y = 0.35
# x = 0.16, y = 0.46
# x = -0.79, y = 0.87

# %%
import matplotlib.pyplot as plt 
x1 = 0.4 
y1 = 0.9

x2 = -0.5
y2 = -0.3

plt.plot(x1,y1,"*-")
plt.plot(x2,y2,"*-")
plt.show()

# %%
h = 0
import math
import random as rnd
for x in range(1,100):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    i = math.sqrt(x**2 + y**2)
    print(i)
    if i > 1:
        print("utnför")
    else:
        h+= 1
        print(f"innanför.............{h}")
print(4*(h/100))
# Out:
# 0.9260284105336091
# innanför.............1
# 0.6653568914440819
# innanför.............2
# 0.46620251348241165
# innanför.............3
# 0.7653631960404143
# innanför.............4
# 1.067870982809464
# utnför
# 0.910281862710817
# innanför.............5
# 0.8192536208102117
# innanför.............6
# 0.33085651263811244
# innanför.............7
# 0.9920181664895714
# innanför.............8
# 0.8072753326479456
# innanför.............9
# 1.0364524894661435
# utnför
# 0.7821190172105509
# innanför.............10
# 0.5331066396475732
# innanför.............11
# 0.8316961041703022
# innanför.............12
# 0.8386948803736194
# innanför.............13
# 0.7474918586753911
# innanför.............14
# 0.5310854957419422
# innanför.............15
# 0.9703357821319655
# innanför.............16
# 0.7952537556459647
# innanför.............17
# 0.8581766287234186
# innanför.............18
# 0.8794081180736981
# innanför.............19
# 0.44000178223373565
# innanför.............20
# 0.43434624156364915
# innanför.............21
# 0.9737439391677499
# innanför.............22
# 1.1223501893240075
# utnför
# 0.6450215569564121
# innanför.............23
# 0.7865148470833219
# innanför.............24
# 0.6102934126306386
# innanför.............25
# 0.9700356488876666
# innanför.............26
# 0.9376317180553067
# innanför.............27
# 0.5934751057677184
# innanför.............28
# 0.8976905232764754
# innanför.............29
# 0.48194375195854294
# innanför.............30
# 0.718403718479922
# innanför.............31
# 1.0078013891391309
# utnför
# 1.0130313681733876
# utnför
# 0.40043764866885423
# innanför.............32
# 1.0299431406423485
# utnför
# 1.1025811245684962
# utnför
# 0.7422848050447534
# innanför.............33
# 0.7272083451806223
# innanför.............34
# 0.7335746753735571
# innanför.............35
# 0.9373759815405915
# innanför.............36
# 0.5963046036829084
# innanför.............37
# 1.0222515926816642
# utnför
# 1.3006224395894328
# utnför
# 1.1302748055710836
# utnför
# 0.6572854651099372
# innanför.............38
# 0.573989956497033
# innanför.............39
# 0.7110887372745224
# innanför.............40
# 1.0607783683316423
# utnför
# 0.3428697955568145
# innanför.............41
# 0.5872592290168637
# innanför.............42
# 1.175034178936794
# utnför
# 0.7347443538395625
# innanför.............43
# 0.9823127715620903
# innanför.............44
# 0.6647976161956851
# innanför.............45
# 0.9159705808794852
# innanför.............46
# 0.8912593337780429
# innanför.............47
# 0.24736344952424624
# innanför.............48
# 0.978253790215682
# innanför.............49
# 0.6015951711030133
# innanför.............50
# 1.2718083743102493
# utnför
# 0.5775390810113666
# innanför.............51
# 0.5015245505308956
# innanför.............52
# 1.2156013906975034
# utnför
# 0.8970945122673311
# innanför.............53
# 1.3220661148202322
# utnför
# 0.4825264165030347
# innanför.............54
# 1.0353365728979669
# utnför
# 0.7070494312882727
# innanför.............55
# 1.175033520122292
# utnför
# 0.6944203865992344
# innanför.............56
# 0.9207888882693932
# innanför.............57
# 0.7874617944829163
# innanför.............58
# 0.7564503041768568
# innanför.............59
# 1.2123324006875604
# utnför
# 0.4474791220658623
# innanför.............60
# 0.24359078827452016
# innanför.............61
# 0.9093451484226895
# innanför.............62
# 1.0289815608700623
# utnför
# 0.8177230502938444
# innanför.............63
# 0.9963988216167478
# innanför.............64
# 0.6528200604432343
# innanför.............65
# 0.4686441255110093
# innanför.............66
# 0.965044194414078
# innanför.............67
# 0.8704176878949311
# innanför.............68
# 1.0929170959106007
# utnför
# 0.6724866928270689
# innanför.............69
# 0.8812597745426803
# innanför.............70
# 0.07522829921321439
# innanför.............71
# 0.7650894226799287
# innanför.............72
# 0.4052418569949839
# innanför.............73
# 0.29362651326217926
# innanför.............74
# 0.6599321901245311
# innanför.............75
# 0.9984400912583105
# innanför.............76
# 0.6831304960219557
# innanför.............77
# 0.863766982824183
# innanför.............78
# 0.792183674645004
# innanför.............79
# 3.16

# %%
import math
import random as rnd
import matplotlib.pyplot as plt
for x in range(1,10000):
    x = rnd.uniform(-1,1)
    y = rnd.uniform(-1,1)
    i = math.sqrt(x**2 + y**2)
    if i > 1:
        plt.plot(x , y, "r*-")
    else:
        plt.plot(x , y, "g*-")
plt.show()
