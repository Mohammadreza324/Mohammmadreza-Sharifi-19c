# %% [markdown]
# # UPPG 1

# %%
import pandas as pd

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1) 
df
# Out:
#           sysselsättning     ålder      kön    2019
# 0      förvärvsarbetande  16-19 år      män   58826
# 1      förvärvsarbetande  16-19 år  kvinnor   72847
# 2      förvärvsarbetande  20-24 år      män  192696
# 3      förvärvsarbetande  20-24 år  kvinnor  174074
# 4      förvärvsarbetande  25-29 år      män  293352
# 5      förvärvsarbetande  25-29 år  kvinnor  268587
# 6      förvärvsarbetande  30-34 år      män  303019
# 7      förvärvsarbetande  30-34 år  kvinnor  271975
# 8      förvärvsarbetande  35-39 år      män  280522
# 9      förvärvsarbetande  35-39 år  kvinnor  255391
# 10     förvärvsarbetande  40-44 år      män  275085
# 11     förvärvsarbetande  40-44 år  kvinnor  260093
# 12  ej förvärvsarbetande  16-19 år      män  176860
# 13  ej förvärvsarbetande  16-19 år  kvinnor  143432
# 14  ej förvärvsarbetande  20-24 år      män  117928
# 15  ej förvärvsarbetande  20-24 år  kvinnor  103001
# 16  ej förvärvsarbetande  25-29 år      män   86633
# ...

# %%
import pandas as pd

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1) 
df_f= df[df["sysselsättning"]=="förvärvsarbetande"]
ja = df_f["2019"].sum()
df_j = df[df["sysselsättning"]=="ej förvärvsarbetande"]
nej = df_j["2019"].sum()
print(f"{ja} personer artbetade och {nej} perosner arbetade inte ")
# Out:
# 2706467 personer artbetade och 1070645 perosner arbetade inte

# %%
import matplotlib.pyplot as plt
lista = [ja, nej]
namn = "förvärvsarbetade", "ej förvärvsarbetade"
plt.pie(lista,labels=namn, autopct='%1.1f%%')
plt.title("så många förvärvsarbetade och inte förärvsarbetade under 2019")
plt.show()

# %% [markdown]
# # UPPG 2

# %%
import pandas as pd

pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)
# Out:
#           sysselsättning     ålder      kön    2019
# 0      förvärvsarbetande  16-19 år      män   58826
# 1      förvärvsarbetande  16-19 år  kvinnor   72847
# 2      förvärvsarbetande  20-24 år      män  192696
# 3      förvärvsarbetande  20-24 år  kvinnor  174074
# 4      förvärvsarbetande  25-29 år      män  293352
# 5      förvärvsarbetande  25-29 år  kvinnor  268587
# 6      förvärvsarbetande  30-34 år      män  303019
# 7      förvärvsarbetande  30-34 år  kvinnor  271975
# 8      förvärvsarbetande  35-39 år      män  280522
# 9      förvärvsarbetande  35-39 år  kvinnor  255391
# 10     förvärvsarbetande  40-44 år      män  275085
# 11     förvärvsarbetande  40-44 år  kvinnor  260093
# 12  ej förvärvsarbetande  16-19 år      män  176860
# 13  ej förvärvsarbetande  16-19 år  kvinnor  143432
# 14  ej förvärvsarbetande  20-24 år      män  117928
# 15  ej förvärvsarbetande  20-24 år  kvinnor  103001
# 16  ej förvärvsarbetande  25-29 år      män   86633
# ...

# %%
import pandas as pd

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)
df_f = df[df["sysselsättning"]=="förvärvsarbetande"]
df_m = df_f[df_f["kön"]=="män"]
män = df_m["2019"].sum()

df_k = df_f[df_f["kön"]=="kvinnor"]
kvinnor = df_k["2019"].sum()

print(f"mellan ålder 16-44 jobbade {män} män och {kvinnor} kvinnor")
# Out:
# mellan ålder 16-44 jobbade 1403500 män och 1302967 kvinnor

# %%
import pandas as pd 

df = pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)
df_ej = df[df["sysselsättning"]== "ej förvärvsarbetande"]

df_m = df_ej[df_ej["kön"]== "män"]
man = df_m["2019"].sum()

df_k = df_ej[df_ej["kön"]=="kvinnor"]
kvinna = df_k["2019"].sum()
print(f"mellan ålder 16-44 jobbade {man} män och {kvinna} kvinnor")
# Out:
# mellan ålder 16-44 jobbade 545813 män och 524832 kvinnor

# %%
import matplotlib.pyplot as plt

lista = [män, kvinnor, kvinna, man]
beskrivning = "män arbetade", "kvinnor arbetade", "kvinnor ej arbetade", "män ej arbetade"
färger = "gold", "lightskyblue", "yellowgreen", "red"

plt.bar(beskrivning, lista, color=färger)
plt.title("män och kvinnor mellan 16-44 som förärvsarbetade och inte")
#plt.axis("equal")
plt.xticks(beskrivning, rotation=90)
plt.show()

# %% [markdown]
# # UPPG 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.read_csv("sysselsattning.csv", encoding="ISO-8859-1", header=1)

df = df[df["sysselsättning"]=="förvärvsarbetande"]

kön = df[df["kön"]=="män"]
ålder = kön["ålder"]
antal = kön["2019"]

k = df[df["kön"]=="kvinnor"]
å = k["ålder"]
a = k["2019"]


plt.plot(ålder, antal, label="män")
plt.plot(å,a, label="kvinna")
plt.title("förändingen av antal förärvsarbetande kvinnor & män i olika ålder")
plt.xlabel("ålder")
plt.ylabel("antal")
plt.legend()

# %% [markdown]
# # UPPG 4

# %%
import pandas as pd
df = pd.read_csv("archive.csv")
land = df[df["Organization Country"]=="Sweden"]
land
# Out:
#      Year   Category                                              Prize  \
# 13   1903  Chemistry                  The Nobel Prize in Chemistry 1903
# 65   1911   Medicine     The Nobel Prize in Physiology or Medicine 1911
# 74   1912    Physics                    The Nobel Prize in Physics 1912
# 121  1924    Physics                    The Nobel Prize in Physics 1924
# 128  1926  Chemistry                  The Nobel Prize in Chemistry 1926
# 146  1929  Chemistry                  The Nobel Prize in Chemistry 1929
# 214  1943  Chemistry                  The Nobel Prize in Chemistry 1943
# 247  1948  Chemistry                  The Nobel Prize in Chemistry 1948
# 301  1955   Medicine     The Nobel Prize in Physiology or Medicine 1955
# 397  1967   Medicine     The Nobel Prize in Physiology or Medicine 1967
# 422  1970   Medicine     The Nobel Prize in Physiology or Medicine 1970
# 425  1970    Physics                    The Nobel Prize in Physics 1970
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("archive.csv")
df.fillna(0)

land = df[df["Organization Country"]=="Sweden"]

antal = land["Category"].value_counts().tolist()
namn = land["Category"].unique()

plt.pie(antal, labels=namn, autopct='%1.1f%%')
plt.title("Swedish nobel prices by category")
plt.show()
print(antal)
print(namn)
# Out:
# [7, 5, 4, 1]
# ['Chemistry' 'Medicine' 'Physics' 'Economics']

# %%
import pandas as pd
import matplotlib.pyplot as plt

lista = pd.read_csv("archive.csv")
tom = lista.dropna()
#kön = lista[lista["Sex"]=="Male" "Female"]

siffra = tom["Sex"].value_counts().tolist()
name = tom["Sex"].unique()

plt.pie(siffra, labels=name)
plt.title(" male and female prices")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("archive.csv")

year = df["Year"].value_counts()

plt.scatter(year.keys(), year.tolist())
plt.title("NUmber of prices per year ")
plt.xlabel("Year")
plt.ylabel("Number of prices")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("archive.csv")
tappa = df.dropna()
länder = tappa["Organization Country"].value_counts()



plt.bar(länder.keys(), länder.tolist())
plt.xticks(länder.keys(), rotation='vertical' )
plt.show()

# %%
import plotly.express as px
import numpy as np 
import pandas as pd 

antal = 1000

tärningar = np.random.randint(1,7,antal) # simulerar antal tärningskast
utfall = np.bincount(tärningar)[1:] # beräknar frekvensen

# skapat dictionary
frekvens = dict(sida = np.arange(1,7), utfall = utfall)
#print(frekvens)
# skapa dataframe från dictionary
df = pd.DataFrame(frekvens)
#print(df)
print(df)
print(frekvens)
# rita ett stapeldiagram

hi = px.bar(df, x="sida", y="utfall", title=f"{antal}st tärningskast med en tärning")
hi.show()
# Out:
#    sida  utfall
# 0     1     158
# 1     2     183
# 2     3     164
# 3     4     168
# 4     5     162
# 5     6     165
# {'sida': array([1, 2, 3, 4, 5, 6]), 'utfall': array([158, 183, 164, 168, 162, 165], dtype=int64)}

# %%
import plotly.express as px

df = px.data.gapminder().query("country=='Canada'")
fig = px.line(df, x="year", y="lifeExp", title='Life expectancy in Canada')
fig.show()

# %%
fig.write_html("", auto_open=true)
